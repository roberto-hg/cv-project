# %% [markdown]
# This file splits the hippocampus dataset and labels into many 2d images per 3d image

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import imageio

# %%
# path to images
im_folder = 'C:/Users/noam_/Documents/Cornell/ComputerVision/Task04_Hippocampus/imagesTr/'
im_folder_labels = 'C:/Users/noam_/Documents/Cornell/ComputerVision/Task04_Hippocampus/labelsTr/'

# path to output files
out_folder = 'C:/Users/noam_/Documents/Cornell/ComputerVision/Task04_Hippocampus/imagesSplit/'
out_folder_l = 'C:/Users/noam_/Documents/Cornell/ComputerVision/Task04_Hippocampus/labelsSplit/'

# %%
def pad_zeros(i):
    if i < 10:
        return "00" + str(i)
    elif i < 100:
        return "0" + str(i)
    else:
        return str(i)

# %%
# loop through images in folder and split into many 2d images
for i in range(1, 50):   # 394 total hippocampus images in folder
    ind = pad_zeros(i)
    im = 'hippocampus_' + ind +'.nii.gz'
    try:       
        print("Currently splitting %s image" % im)
        im_load = nib.load(im_folder + im)
        im_data = im_load.get_fdata()
        x,y,z = im_data.shape
        for j in range(1,z):
            name = out_folder + str(j) + 'hippocampus_' + ind + '.jpg'
            imageio.imwrite(name, im[:, :, 0])
            
        print("Currently splitting %s labels" % im)
        im_load = nib.load(im_folder_labels + im)
        im_data = im_load.get_fdata()
        x,y,z = im_data.shape
        for j in range(1,z):
            name = out_folder_l + 'l' + str(j) + 'hippocampus_' + ind + '.jpg'
            scipy.misc.imsave(name, im_data[:,:,j])
        
    except:
        print("file", im, "does not exist")
# Out:
# Currently splitting hippocampus_001.nii.gz image
# file hippocampus_001.nii.gz does not exist
# Currently splitting hippocampus_002.nii.gz image
# file hippocampus_002.nii.gz does not exist
# Currently splitting hippocampus_003.nii.gz image
# file hippocampus_003.nii.gz does not exist
# Currently splitting hippocampus_004.nii.gz image
# file hippocampus_004.nii.gz does not exist
# Currently splitting hippocampus_005.nii.gz image
# file hippocampus_005.nii.gz does not exist
# Currently splitting hippocampus_006.nii.gz image
# file hippocampus_006.nii.gz does not exist
# Currently splitting hippocampus_007.nii.gz image
# file hippocampus_007.nii.gz does not exist
# Currently splitting hippocampus_008.nii.gz image
# file hippocampus_008.nii.gz does not exist
# Currently splitting hippocampus_009.nii.gz image
# file hippocampus_009.nii.gz does not exist
# Currently splitting hippocampus_010.nii.gz image
# file hippocampus_010.nii.gz does not exist
# ...
