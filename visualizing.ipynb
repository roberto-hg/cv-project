# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
# path to image
epi_img = nib.load('/Users/varshakishore/Downloads/Task04_Hippocampus/imagesTr/hippocampus_203.nii.gz')
epi_img_l = nib.load('/Users/varshakishore/Downloads/Task04_Hippocampus/labelsTr/hippocampus_203.nii.gz')
epi_img_data = epi_img.get_fdata()
epi_img_data.shape
slice_0 = epi_img_data[15,:,:]
plt.imshow(slice_0)
plt.show()

# %%
epi_img_data_l = epi_img_l.get_fdata()
epi_img_data_l.shape
slice_0 = epi_img_data_l[15,:,:]
plt.imshow(slice_0)
plt.show()
